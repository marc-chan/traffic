# %% [markdown]
# ### 1. Pull Traffic API
#
# This notebook uses the api provided at [data.gov.sg](https://api.data.gov.sg/v1/transport/traffic-images) to compile a set of traffic camera image url links.

# %%
import requests
import pprint
import datetime
from config import config


API_KEY = config["C_KEY"]
URL = "https://api.data.gov.sg/v1/transport/traffic-images"
pp = pprint.PrettyPrinter(indent=2)

# %%
def get_one_traffic_data(date_time):
    r = requests.get(URL, params={"date_time": date_time}, headers={"api-key": API_KEY})
    data = r.json()
    return data

# %%
#test to see if working
test_date_time = "2017-05-07T09:54:00"
test_data = get_one_traffic_data(test_date_time)
pp.pprint(test_data)
# Out:
# { 'api_info': {'status': 'healthy'},
#   'items': [ { 'cameras': [ { 'camera_id': '1701',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/31af8e44-a762-44ce-90fd-cd3f804b528a.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '1ae3ec73d11d3e80f1169f979434bc84',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.323604823,
#                                             'longitude': 103.8587802},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '1704',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/42983cc9-8d6e-4665-bb8d-481b3c73f929.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '60975493c97a3fe31f07011e128c554b',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.28569398886979,
#                                             'longitude': 103.837524510188},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '1705',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/0a3e17c9-5a5c-4dde-a521-614b12c79294.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '86564e1f6b8d48f96c650fde0b94e6d4',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.375925022,
#                                             'longitude': 103.8587986},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '1706',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/03e04402-e4cb-4d0e-a5df-e84d69a0e6e1.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': 'a879d58e64f1802ca977816d5441601e',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.38861,
#                                             'longitude': 103.85806},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '1707',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/cf672911-705e-437c-b281-4817154454f4.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '4b3318942a1c4a02cee3f4ff8272ff03',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.28036584335876,
#                                             'longitude': 103.830451146503},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '1709',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/cf0f3094-697f-4627-8047-73c0edb87060.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': 'a2a2f032c1921938065bf808c4fe754f',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.31384231654635,
#                                             'longitude': 103.845603032574},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2701',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/0ece07bb-fe47-49a5-9d85-c2f80522325f.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '6af9760a55647878f7d818d4cfe93483',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.447023728,
#                                             'longitude': 103.7716543},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2702',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/67937823-dcbd-493d-b33b-82fb45cc9357.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '1e93ee765ad9ad3bc6f106d583328756',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.445554109,
#                                             'longitude': 103.7683397},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2703',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/0347a37b-e763-4516-a9a8-ffc7dc75f829.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '7b62e3221e588b35e2ff0aa844f6b7e3',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.35047790791386,
#                                             'longitude': 103.791033581325},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2704',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/bbc272f6-4041-4b2b-9f8b-ee90eeb8dc79.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': 'ccbdbae18df98667a91987842227f51c',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.429588536,
#                                             'longitude': 103.769311},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2705',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/9fc6571c-a943-47c1-a28c-ccf2576a7e41.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': 'aa9bbabb0164b84d7ec0e5577d13608f',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.36728572,
#                                             'longitude': 103.7794698},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2706',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/b5e985f6-7eb2-4930-a3c8-bffc56a4795d.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '049cf973c33363dc88f74f67ef8a55f1',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.414142,
#                                             'longitude': 103.771168},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2707',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/b7b1c9b2-3734-4ef0-b427-c60b6e9585ff.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '4679e75f5155f444b49a7379ec04ffb3',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.3983,
#                                             'longitude': 103.774247},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '2708',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/de1f5f21-03a6-4dac-bc6d-2522007382f5.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '7c8eaf0ae4c2145a6c0adb17e565bea8',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.3865,
#                                             'longitude': 103.7747},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '3702',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/e0d79e0e-e174-4912-8597-027ad24fbee4.jpg',
#                               'image_metadata': { 'height': 480,
#                                                   'md5': '2c722faabf781cf3cb63204b09ffd368',
#                                                   'width': 640},
#                               'location': { 'latitude': 1.33831,
#                                             'longitude': 103.98032},
#                               'timestamp': '2017-05-07T09:53:14+08:00'},
#                             { 'camera_id': '

#                                                   'width': 320},
#                               'location': { 'latitude': 1.357098686,
#                                             'longitude': 103.902042},
#                               'timestamp': '2017-05-07T09:40:13+08:00'},
#                             { 'camera_id': '1502',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/d6188652-52ed-4c9c-b16e-450c1f5df2ef.jpg',
#                               'image_metadata': { 'height': 240,
#                                                   'md5': 'd8f46003227dff0ba3988c2de900fb66',
#                                                   'width': 320},
#                               'location': { 'latitude': 1.27135090682664,
#                                             'longitude': 103.861828440597},
#                               'timestamp': '2017-05-07T09:35:13+08:00'},
#                             { 'camera_id': '1001',
#                               'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/264457c5-8923-4c2c-886f-0d92f330cff6.jpg',
#                               'image_metadata': { 'height': 240,
#                                                   'md5': '57b1c2a29cfa1161dbc7bbf4333db336',
#                                                   'width': 320},
#                               'location': { 'latitude': 1.29531332,
#                                             'longitude': 103.871146},
#                               'timestamp': '2017-05-07T09:30:13+08:00'}],
#                'timestamp': '2017-05-07T09:53:54+08:00'}]}

# %% [markdown]
# ### Data structure of json response
#
# - items[0] (dict)
#  - timestamp (str)
#  - cameras (arr)
#    - **camera_id** (str)
#    - **image** (str url)
#    - **image_metadata** (dict)
#      - *height (int)*
#      - *width (int)*
#      - *md5 (str)*
#    - **location** (dict)
#      - *latitude (float64)*
#      - *longitude (float64)*
#    - **timestamp** (str)
# - api_info (dict)
#  - status (str)

# %%
#Display structure of a single camera record
pp.pprint(test_data["items"][0]["cameras"][0])
# Out:
# { 'camera_id': '1701',
#   'image': 'https://images.data.gov.sg/api/traffic-images/2017/05/31af8e44-a762-44ce-90fd-cd3f804b528a.jpg',
#   'image_metadata': { 'height': 480,
#                       'md5': '1ae3ec73d11d3e80f1169f979434bc84',
#                       'width': 640},
#   'location': {'latitude': 1.323604823, 'longitude': 103.8587802},
#   'timestamp': '2017-05-07T09:53:14+08:00'}

# %%
def convert_timestring(dt):
    #Format required for api query: YYYY-MM-DD[T]HH:MM:SS+08:00'
    return dt.strftime("%Y-%m-%dT%X+08:00")

def collect_traffic_data(start_dt, end_dt):
    #container to store data collected
    data = []
    md5_store = []
    
    #Camera data updated approximately every 3 mins,so set checking interval to 1 min.
    interval = datetime.timedelta(minutes=15)
    count = 0
    dt = start_dt
    prev_time_string = ""
    while dt < end_dt:
        #Try/Except block to handle network error
        try:
            raw = get_one_traffic_data(convert_timestring(dt))
            #Try/Except block to handle data return errors (e.g. traffic camera down)
            try:
                for cam in raw["items"][0]["cameras"]:
                    if cam["image_metadata"]["md5"] in md5_store:
                        continue
                    row = [cam["camera_id"], 
                           cam["image"],
                           cam["image_metadata"]["height"],
                           cam["image_metadata"]["width"],
                           cam["image_metadata"]["md5"],
                           cam["location"]["latitude"],
                           cam["location"]["longitude"],
                           cam["timestamp"]]
                    md5_store.append(cam["image_metadata"]["md5"])
                    data.append(row)
            except:
                print("Encountered data exception... Continuing...")
            dt += interval
            count += 1
            if count % (24*4) == 0:
                print("Day {} done!".format(count/24/4))
        except:
            print("Encountered network exception... Retrying...")
            continue
    return data

# %%
#Collect 4 months of data from 2016-01 to 2016-04
from dateutil.relativedelta import relativedelta

year = 2016
month = 12
full_data = []
num_months = 4

for _ in range(num_months):
    start_date = datetime.datetime(year,month,1,0,0,0,0)
    end_date = start_date+relativedelta(months=1)
    print("Running {}-{}...".format(year,month))
    d = collect_traffic_data(start_date, end_date)
    full_data.extend(d)
    print("{}-{}: done!".format(year,month))
    
    if month <= 11:
        year = year
        month += 1
    else:
        year += 1
        month = 1
# Out:
# Running 2016-12...
# Day 1.0 done!
# Day 2.0 done!
# Day 3.0 done!
# Day 4.0 done!
# Day 5.0 done!
# Day 6.0 done!
# Day 7.0 done!
# Day 8.0 done!
# Day 9.0 done!
# Day 10.0 done!
# Day 11.0 done!
# Day 12.0 done!
# Day 13.0 done!
# Day 14.0 done!
# Day 15.0 done!
# Day 16.0 done!
# Day 17.0 done!
# Day 18.0 done!
# Day 19.0 done!
# Day 20.0 done!
# Day 21.0 done!
# Day 22.0 done!
# Day 23.0 done!
# Day 24.0 done!
# Day 25.0 done!
# Day 26.0 done!
# Day 27.0 done!
# Day 28.0 done!
# Day 29.0 done!
# Day 30.0 done!
# Day 31.0 done!
# 2016-12: done!
# Running 2017-1...
# Day 1.0 done!
# Day 2.0 done!
# Day 3.0 done!
# Day 4.0 done!
# Day 5.0 done!
# Day 6.0 done!
# Day 7.0 done!
# Day 8.0 done!
# Day 9.0 done!
# Day 10.0 done!
# Day 11.0 done!
# Day 12.0 done!
# Day 13.0 done!
# Day 14.0 done!
# Day 15.0 done!
# Day 16.0 done!
# Day 17.0 done!
# Day 18.0 done!
# Day 19.0 done!
# Day 20.0 done!
# Day 21.0 done!
# Day 22.0 done!
# Day 23.0 done!
# Day 24.0 done!
# Day 25.0 done!
# Day 26.0 done!
# Day 27.0 done!
# Day 28.0 done!
# Day 29.0 done!
# Day 30.0 done!
# Day 31.0 done!
# 2017-1: done!
# Running 2017-2...
# Day 1.0 done!
# Day 2.0 done!
# Day 3.0 done!
# Day 4.0 done!
# Day 5.0 done!
# Day 6.0 done!
# Day 7.0 done!
# Day 8.0 done!
# Day 9.0 done!
# Day 10.0 done!
# Day 11.0 done!
# Day 12.0 done!
# Day 13.0 done!
# Day 14.0 done!
# Day 15.0 done!
# Day 16.0 done!
# Day 17.0 done!
# Day 18.0 done!
# Day 19.0 done!
# Day 20.0 done!
# Day 21.0 done!
# Day 22.0 done!
# Day 23.0 done!
# Day 24.0 done!
# Day 25.0 done!
# Day 26.0 done!
# Day 27.0 done!
# Day 28.0 done!
# 2017-2: done!
# Running 2017-3...
# Day 1.0 done!
# Day 2.0 done!
# Day 3.0 done!
# Day 4.0 done!
# Day 5.0 done!
# Day 6.0 done!
# Day 7.0 done!
# Day 8.0 done!
# Day 9.0 done!
# Day 10.0 done!
# Day 11.0 done!
# Day 12.0 done!
# Day 13.0 done!
# Day 14.0 done!
# Day 15.0 done!
# Day 16.0 done!
# Day 17.0 done!
# Day 18.0 done!
# Day 19.0 done!
# Day 20.0 done!
# Day 21.0 done!
# Day 22.0 done!
# Day 23.0 done!
# Day 24.0 done!
# Day 25.0 done!
# Day 26.0 done!
# Day 27.0 done!
# Day 28.0 done!
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Day 29.0 done!
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Encountered data exception... Continuing...
# Day 30.0 done!
# Day 31.0 done!
# 2017-3: done!

# %%
len(full_data)
# Out:
# 842760

# %%
#Save compiled records into pickle file
import pickle
pickle.dump(full_data, open( "camera_links.p", "rb" ) )
